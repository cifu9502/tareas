# %%
# %pylab inline
import wave
import sys
from __future__ import division


spf = wave.open('nombre.wav','r')

#Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, 'Int16')
fs = spf.getframerate()

if spf.getnchannels() == 2:
    print 'Just mono files'
    sys.exit(0)

t = linspace(0, len(signal)/fs, num=len(signal))
title('Signal Wave...')
plot( t,signal)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fft']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
from scipy.fftpack import fft, fftfreq
signalf = fft(signal)/n

absf = abs(signalf)

n = len(signal)

freq = fftfreq(n, (1/fs)) # Recuperamos las frecuencias

plot(freq, abs(signalf))

# %%
sigShif = np.fft.fftshift(absf)
freqShif = np.fft.fftshift(freq)
plot(freqShif, sigShif)

# %%
freq_cut = 20
sigShif[ abs(freqShif) < freq_cut] = 0
sigShif
plot(freqShif, sigShif)

# %%
absf[abs(freq) < 20] = 0

a = max(absf)
b= freq[(absf == a) & (freq > 0)]

# %%
print("%f" % b)
# Out:
# 126.627604
